# %% [markdown]
# ##
# ===================================
# ==================
# # project : Udemy Courses Analysis
# # Auther : Mahmoud Atef
# # Goal : Analyze Cafe SalesData, Perform Data Cleaning And (EDA) And Generate
# # Business Insights & KPI
# ##
# ===================================
# ===================

# %%
# =========================
# Import Libraries
# =========================
import pandas as pd # Pandas Data Manipulation And Analysis
import numpy as np  # Numpy Numerical Operations And Mathematical Calculations

import seaborn as sns # Seaborn Statistical Data Visul
import matplotlib.pyplot as plt # Matplot Basic Data Visul

import plotly.express as px # Plotly Interactive Data Visul
import missingno as msno    # Missingno Visuliz Missing Values

# =========================
# End Import Libraies 
# =========================

# %% [markdown]
# # 1. # Read Dataset

# %%
# ====================
# Read DataSet
# ====================

df = pd.read_csv('Udemy (1).csv')

# ====================
# End Read Data
# ====================

# %% [markdown]
# # 2. # Data Overview

# %%
# Step 1 
# Display First 10 Rows

df.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    TRUE   200
# 1      https://www.udemy.com/goods-and-services-tax/    TRUE    75
# ...

# %%
# step 2 
# Display Last 10 Rows

df.tail(10)
# Out:
#       course_id                                       course_title  \
# 3673     270976                             A how to guide in HTML
# 3674     679992                  Building Better APIs with GraphQL
# 3675     330900  Learn Grunt with Examples: Automate Your Front...
# 3676     667122  Build A Stock Downloader With Visual Studio 20...
# 3677     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3678     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3679    1088178  How To Design A WordPress Website With No Codi...
# 3680     635248                      Learn and Build using Polymer
# 3681     905096  CSS Animations: Create Amazing Effects on Your...
# 3682     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url is_paid price  \
# 3673      https://www.udemy.com/a-how-to-guide-in-html/   FALSE  Free
# 3674  https://www.udemy.com/building-better-apis-wit...    TRUE    50
# ...

# %% [markdown]
# # Dataset Must Have 3683 Rows And 12 Columns

# %%
# Step 3 
# Explor Number Of Columns And Rows For Dataset

df.shape
# Out:
# (3683, 12)

# %% [markdown]
# Type Of Dataset

# %%
# Step 3
# Explor Meta Data

df.info()

# must Have Error Meta Data Some Columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3683 non-null   int64
#  1   course_title         3683 non-null   object
#  2   url                  3683 non-null   object
#  3   is_paid              3683 non-null   object
#  4   price                3675 non-null   object
#  5   num_subscribers      2872 non-null   float64
#  6   num_reviews          2872 non-null   float64
#  7   num_lectures         2877 non-null   float64
#  8   level                3683 non-null   object
#  9   content_duration     3682 non-null   object
#  10  published_timestamp  3683 non-null   object
#  11  subject              3683 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 345.4+ KB

# %%
# step 4 
# statistica Summary For Numerical Data

df.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.683000e+03      2872.000000   2872.000000   2877.000000
# mean   6.764546e+05      3141.410864    162.386838     39.691693
# std    3.437217e+05      9474.176512    956.930695     49.370148
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.077270e+05       109.750000      5.000000     15.000000
# 50%    6.882440e+05       918.000000     18.000000     25.000000
# 75%    9.617290e+05      2597.500000     72.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
# Statistical Summary For Data Object

df.describe(include = 'object')
# Out:
#                                              course_title  \
# count                                                3683
# unique                                               3668
# top     Creating an animated greeting card via Google ...
# freq                                                    3
#
#                                                 url is_paid price       level  \
# count                                          3683    3683  3675        3683
# unique                                         3677       3    39           5
# top     https://www.udemy.com/microstation-celulas/    TRUE    20  All Levels
# freq                                              2    3372   830        1932
#
#        content_duration   published_timestamp          subject
# count              3682                  3683             3683
# unique              110                  3677                4
# top              1 hour  2014-04-15T21:48:55Z  Web Development
# ...

# %%
# step 5 
# Column Name

df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# step 6
# check Duplicate Rows

df.duplicated().sum()

# Must Have duplicated 2 Rows
# Out:
# np.int64(2)

# %%
# Step 7
# Check Missing Values

df.isna().sum()

# Must Have Missing Values
# Out:
# course_id                0
# course_title             0
# url                      0
# is_paid                  0
# price                    8
# num_subscribers        810
# num_reviews            811
# num_lectures           806
# level                    0
# content_duration         1
# published_timestamp      0
# subject                  0
# dtype: int64

# %%
# cheak Percentige Missing Values For Dataset

df.isna().sum() * 100 / len(df)

# percent Missing Values
# Out:
# course_id               0.000000
# course_title            0.000000
# url                     0.000000
# is_paid                 0.000000
# price                   0.217332
# num_subscribers        22.004890
# num_reviews            22.032057
# num_lectures           21.896224
# level                   0.000000
# content_duration        0.027167
# published_timestamp     0.000000
# subject                 0.000000
# dtype: float64

# %%
# Step 8
# Cheak Missing Visuliz

msno.matrix(df)

# Done Visuliz Missing Values
# Out:
# <Axes: >

# %%
# step 10
# unique Values

df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# =====================
# # End Data Overview
#
# =====================

# %% [markdown]
# ======================
# # Start Data Cleaning
# ======================

# %%
# Step 1 in Data Cleaning

# Find Duplicated in Dataset

df[df.duplicated()]

# This 2 Rows Is Duplicated
# Out:
#       course_id                                       course_title  \
# 897     1035638                 Understanding Financial Statements
# 2566      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url is_paid price  \
# 897   https://www.udemy.com/understanding-financial-...    TRUE    25
# 2566  https://www.udemy.com/build-beautiful-html5-we...    TRUE    75
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 897               0.0          0.0          10.0  All Levels           1 hour
# 2566              NaN        525.0          24.0  All Levels          4 hours
#
#        published_timestamp           subject
# 897   2016-12-15T14:56:17Z  Business Finance
# 2566  2013-01-03T00:55:31Z   Web Development

# %%
# Virify the presence Duplicated in Dataset

df[df.duplicated(keep = False)]
# Out:
#       course_id                                       course_title  \
# 780     1035638                 Understanding Financial Statements
# 897     1035638                 Understanding Financial Statements
# 2483      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
# 2566      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url is_paid price  \
# 780   https://www.udemy.com/understanding-financial-...    TRUE    25
# 897   https://www.udemy.com/understanding-financial-...    TRUE    25
# 2483  https://www.udemy.com/build-beautiful-html5-we...    TRUE    75
# 2566  https://www.udemy.com/build-beautiful-html5-we...    TRUE    75
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 780               0.0          0.0          10.0  All Levels           1 hour
# 897               0.0          0.0          10.0  All Levels           1 hour
# ...

# %% [markdown]
# # Remove Duplicated

# %%
# Drop Duplicated in Dataset

df.drop_duplicates(inplace = True)

# %%
# Done Drop Duplicated

df.duplicated().sum()

# Not Must Have Duplicated
# Out:
# np.int64(0)

# %% [markdown]
# # Handleing Missing Valued

# %%
# percent Missing Values

df.isna().sum() * 100 / len(df)
# Out:
# course_id               0.000000
# course_title            0.000000
# url                     0.000000
# is_paid                 0.000000
# price                   0.217332
# num_subscribers        22.004890
# num_reviews            22.032057
# num_lectures           21.896224
# level                   0.000000
# content_duration        0.027167
# published_timestamp     0.000000
# subject                 0.000000
# dtype: float64

# %%
# Visulize Missing Vaues

msno.bar(df)
# Out:
# <Axes: >

# %%
# Find Rows Must Have Missing Values

df[df.isna().any(axis = 1)]
# Out:
#       course_id                                       course_title  \
# 1       1113822  Complete GST Course & Certification - Grow You...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 5        192870  Trading Penny Stocks: A Guide for All Levels I...
# 6        739964  Investing And Trading For Beginners: Mastering...
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# ...         ...                                                ...
# 3674     679992                  Building Better APIs with GraphQL
# 3676     667122  Build A Stock Downloader With Visual Studio 20...
# 3678     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3679    1088178  How To Design A WordPress Website With No Codi...
# 3682     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url is_paid price  \
# 1         https://www.udemy.com/goods-and-services-tax/    TRUE    75
# ...

# %%
# Number of Rows Must Have Missing Values

df[df.isna().any(axis = 1)].isna().sum()
# Out:
# course_id                0
# course_title             0
# url                      0
# is_paid                  0
# price                    8
# num_subscribers        810
# num_reviews            811
# num_lectures           806
# level                    0
# content_duration         1
# published_timestamp      0
# subject                  0
# dtype: int64

# %%
# Under of Number in Price and content_duration

df[df.isna().any(axis = 1)].head(20)
# Out:
#     course_id                                       course_title  \
# 1     1113822  Complete GST Course & Certification - Grow You...
# 3     1210588  Beginner to Pro - Financial Analysis in Excel ...
# 5      192870  Trading Penny Stocks: A Guide for All Levels I...
# 6      739964  Investing And Trading For Beginners: Mastering...
# 7      403100  Trading Stock Chart Patterns For Immediate, Ex...
# 9     1167710  The Only Investment Strategy You Need For Your...
# 10     592338  Forex Trading Secrets of the Pros With Amazon'...
# 11     975046                    Trading Options With Money Flow
# 13     794151  Forex Trading Course: Work Smarter Not Harder ...
# 15     504036  Short Selling: Learn To Sell Stocks Before The...
# 27     447362  Create Your Own Hedge Fund: Trade Stocks Like ...
# 33    1217778  Mastering High Probability Iron Condor Options...
# 34    1246208              The Complete Short Course on Ethereum
# ...

# %%
# drop null on Price and content_duration

df.dropna(subset = ['price', 'content_duration'], inplace = True)

# %%
# Find Dataset is null

df[df.isna().any(axis = 1)][[
    'num_subscribers',
    'num_reviews',
    'num_lectures'
]]
# Out:
#       num_subscribers  num_reviews  num_lectures
# 1              2792.0        923.0           NaN
# 3              2451.0          NaN          36.0
# 5                 NaN        138.0          25.0
# 6              1540.0        178.0           NaN
# 7                 NaN        148.0          23.0
# ...               ...          ...           ...
# 3674            555.0          NaN          16.0
# 3676            436.0          NaN          22.0
# 3678              NaN         14.0          21.0
# 3679              NaN          3.0          42.0
# 3682              NaN         36.0          20.0
#
# [1922 rows x 3 columns]

# %%
df[[
    'num_subscribers',
    'num_reviews',
    'num_lectures'
   ]].isna().sum()
# Out:
# num_subscribers    804
# num_reviews        809
# num_lectures       804
# dtype: int64

# %%
df[df['num_subscribers'].isna()].head(10)
# Out:
#     course_id                                       course_title  \
# 5      192870  Trading Penny Stocks: A Guide for All Levels I...
# 7      403100  Trading Stock Chart Patterns For Immediate, Ex...
# 9     1167710  The Only Investment Strategy You Need For Your...
# 13     794151  Forex Trading Course: Work Smarter Not Harder ...
# 27     447362  Create Your Own Hedge Fund: Trade Stocks Like ...
# 41    1035472  Python for Finance: Investment Fundamentals & ...
# 44     301442       Black Algo Trading: Build Your Trading Robot
# 45     640100  Accounting & Financial Statement Analysis: Com...
# 47     260470  Forex Robots: Expect To Earn 175% P.A. Forex R...
# 62     165964  Stock Trading Ninja: Complete System For Tradi...
#
#                                                   url is_paid price  \
# 5   https://www.udemy.com/trading-penny-stocks-a-g...    TRUE   150
# 7   https://www.udemy.com/trading-chart-patterns-f...    TRUE    95
# ...

# %%
df[df['num_reviews'].isna()].head(10)
# Out:
#     course_id                                       course_title  \
# 3     1210588  Beginner to Pro - Financial Analysis in Excel ...
# 9     1167710  The Only Investment Strategy You Need For Your...
# 11     975046                    Trading Options With Money Flow
# 15     504036  Short Selling: Learn To Sell Stocks Before The...
# 27     447362  Create Your Own Hedge Fund: Trade Stocks Like ...
# 33    1217778  Mastering High Probability Iron Condor Options...
# 34    1246208              The Complete Short Course on Ethereum
# 35     434774  Options Trading Stocks: Proven Toolbox For Fin...
# 39     965832        The Complete Investment Banking Course 2017
# 46    1247394  Cryptocurrency Trading: Complete Guide To Trad...
#
#                                                   url is_paid price  \
# 3   https://www.udemy.com/complete-excel-finance-c...    TRUE    95
# 9   https://www.udemy.com/the-only-investment-stra...    TRUE   200
# ...

# %%
df[df['num_lectures'].isna()].head(10)
# Out:
#     course_id                                       course_title  \
# 1     1113822  Complete GST Course & Certification - Grow You...
# 6      739964  Investing And Trading For Beginners: Mastering...
# 9     1167710  The Only Investment Strategy You Need For Your...
# 10     592338  Forex Trading Secrets of the Pros With Amazon'...
# 15     504036  Short Selling: Learn To Sell Stocks Before The...
# 34    1246208              The Complete Short Course on Ethereum
# 39     965832        The Complete Investment Banking Course 2017
# 41    1035472  Python for Finance: Investment Fundamentals & ...
# 44     301442       Black Algo Trading: Build Your Trading Robot
# 47     260470  Forex Robots: Expect To Earn 175% P.A. Forex R...
#
#                                                   url is_paid price  \
# 1       https://www.udemy.com/goods-and-services-tax/    TRUE    75
# 6   https://www.udemy.com/investing-and-trading-fo...    TRUE    65
# ...

# %%
# =============================
# Investingating missing values pattern
# ===================

# ======================
# cheak whether missing values are randomly distributed

# or related to a specific subject or course type paid or free

# this help determine the most appropriate cleaning strategy

df[df['num_subscribers'].isna()]['subject'].value_counts()
# Out:
# subject
# Business Finance       268
# Web Development        256
# Musical Instruments    155
# Graphic Design         125
# Name: count, dtype: int64

# %%
df[df['num_reviews'].isna()]['subject'].value_counts()
# Out:
# subject
# Business Finance       273
# Web Development        260
# Musical Instruments    146
# Graphic Design         130
# Name: count, dtype: int64

# %%
df[df['num_lectures'].isna()]['subject'].value_counts()
# Out:
# subject
# Business Finance       268
# Web Development        251
# Musical Instruments    144
# Graphic Design         141
# Name: count, dtype: int64

# %%
df[df['num_subscribers'].isna()]['is_paid'].value_counts()
# Out:
# is_paid
# TRUE     733
# FALSE     71
# Name: count, dtype: int64

# %%
df[df['num_reviews'].isna()]['is_paid'].value_counts()
# Out:
# is_paid
# TRUE     745
# FALSE     64
# Name: count, dtype: int64

# %%
df[df['num_lectures'].isna()]['is_paid'].value_counts()
# Out:
# is_paid
# TRUE     751
# FALSE     53
# Name: count, dtype: int64

# %% [markdown]
# # Finding
# Missing Values appear across all course subject
#
# Most missing values belong to paid courses
#
# No evidence that missing values are limited to one specific category
#
# Futher onvestigation is required before choosing between imputating or row removal

# %%
# Explore Must outliers

df[['num_subscribers', 'num_reviews', 'num_lectures']].describe()
# Out:
#        num_subscribers   num_reviews  num_lectures
# count      2868.000000   2863.000000   2868.000000
# mean       3145.736750    162.662242     39.736402
# std        9480.074347    958.378686     49.436711
# min           0.000000      0.000000      0.000000
# 25%         111.000000      5.000000     15.000000
# 50%         921.000000     18.000000     25.000000
# 75%        2603.000000     72.000000     45.000000
# max      268923.000000  27445.000000    779.000000

# %% [markdown]
# # Outliers Detection
# Boxplot Were used detect potential outliers in the
# numercial features

# %%
fig = px.box(df, x = ['num_subscribers'])
fig.show()

# %%
fig2 = px.box(df, x = ['num_reviews'])
fig2.show()

# %%
fig3 = px.box(df, x = ['num_lectures'])
fig3.show()

# %% [markdown]
# ### Observation
# - Outliers Found in all three columns
#
# - All distributions are right-skewed
#
# - Outliers will be investigated before removal

# %%
# Missing values Imputewtion 


df['num_subscribers'].fillna(df['num_subscribers'].median(), inplace = True) # Imputation by using Median Becouse Must Have Outliers in column 

df['num_reviews'].fillna(df['num_reviews'].median(), inplace = True) # Imputation by using median 

df['num_lectures'].fillna(df['num_lectures'].median(), inplace = True) # Imputation by using Median
# Out:
# C:\Users\AsUs\AppData\Local\Temp\ipykernel_10880\3834158515.py:4: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\AsUs\AppData\Local\Temp\ipykernel_10880\3834158515.py:6: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ## Since The numerical features are right-skewed and contain outliers # missing values were imputed using median instead mean

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# # NO Missing Values End the Handling Missing Values

# %% [markdown]
# # Handling outliers

# %%
Q1 = df['num_subscribers'].quantile(0.25)

Q3 = df['num_subscribers'].quantile(0.75)
# Out:
# np.float64(228.0)

# %%
IQR = Q3 - Q1
# Out:
# np.float64(1621.25)

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
# Out:
# Q1: 228.0
# Q3: 1849.25
# IQR: 1621.25
# Lower Bound: -2203.875
# Upper Bound: 4281.125

# %%
Feature = {'Q1': 228,
           'Q3': 1849,
           'IQR': 1621,
           'upper bound': 4281
          }

# %%
outliers_df = df[df['num_subscribers'] > upper_bound]
outliers_df.shape
# Out:
# (491, 12)

# %%
outliers_df['subject'].value_counts()
# Out:
# subject
# Web Development        348
# Business Finance        75
# Graphic Design          38
# Musical Instruments     30
# Name: count, dtype: int64

# %%
outliers_df[['course_title', 'subject','num_subscribers']]\
    .sort_values(by = 'num_subscribers', ascending = False)\
    .head(20)
# Out:
#                                            course_title              subject  \
# 2832               Learn HTML5 Programming From Scratch      Web Development
# 3037                     Coding for Entrepreneurs Basic      Web Development
# 3235                         The Web Developer Bootcamp      Web Development
# 1900              Free Beginner Electric Guitar Lessons  Musical Instruments
# 2594  Web Design for Web Developers: Build Beautiful...      Web Development
# 3294  Practical PHP: Master the Basics and Code Dyna...      Web Development
# 3252          JavaScript: Understanding the Weird Parts      Web Development
# 1983  Pianoforall - Incredible New Way To Learn Pian...  Musical Instruments
# 3209  Angular 4 (formerly Angular 2) - The Complete ...      Web Development
# 3670               Beginner Photoshop to HTML5 and CSS3      Web Development
# 2787  Web Development By Doing: HTML / CSS From Scratch      Web Development
# ...

# %%
Q1 = df['num_reviews'].quantile(0.25)
Q3 = df['num_reviews'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
# Out:
# Q1: 7.0
# Q3: 47.0
# IQR: 40.0
# Lower Bound: -53.0
# Upper Bound: 107.0

# %%
outliers_reviews = df[df['num_reviews'] > upper_bound]
outliers_reviews.shape
# Out:
# (556, 12)

# %%
outliers_reviews['subject'].value_counts()
# Out:
# subject
# Web Development        351
# Business Finance       107
# Graphic Design          60
# Musical Instruments     38
# Name: count, dtype: int64

# %%
outliers_reviews[['course_title', 'subject', 'num_reviews']]\
    .sort_values(by = 'num_reviews', ascending = False)\
    .head(20)
# Out:
#                                            course_title              subject  \
# 3235                         The Web Developer Bootcamp      Web Development
# 3237              The Complete Web Developer Course 2.0      Web Development
# 3209  Angular 4 (formerly Angular 2) - The Complete ...      Web Development
# 3259                            Modern React with Redux      Web Development
# 3256                        Learn and Understand NodeJS      Web Development
# 2832               Learn HTML5 Programming From Scratch      Web Development
# 3233  Angular 2 with TypeScript for Beginners: The P...      Web Development
# 1983  Pianoforall - Incredible New Way To Learn Pian...  Musical Instruments
# 2594  Web Design for Web Developers: Build Beautiful...      Web Development
# 2788  Build Your First Website in 1 Week with HTML5 ...      Web Development
# 3330  HTML and CSS for Beginners - Build a Website &...      Web Development
# ...

# %%
Q1 = df['num_lectures'].quantile(0.25)

Q3 = df['num_lectures'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR}")
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
# Out:
# Q1: 17.0
# Q3: 37.0
# IQR: 20.0
# Lower Bound: -13.0
# Upper Bound: 67.0

# %%
outlier_lectures = df[df['num_lectures'] > upper_bound]
outlier_lectures.shape
# Out:
# (393, 12)

# %%
outlier_lectures['subject'].value_counts()
# Out:
# subject
# Web Development        218
# Musical Instruments     69
# Business Finance        62
# Graphic Design          44
# Name: count, dtype: int64

# %%
outlier_lectures[['course_title', 'subject', 'num_lectures']]\
    .sort_values(by = 'num_lectures', ascending = False)\
    .head(20)
# Out:
#                                            course_title              subject  \
# 2712  Back to School Web Development and Programming...      Web Development
# 162                             Learn to Trade The News     Business Finance
# 563             Financial Management - A Complete Study     Business Finance
# 3009  Code & Grow Rich:  Earn More As An Entrepreneu...      Web Development
# 657   MCA Accountancy and Financial Management -Pape...     Business Finance
# 2618  Become a Professional Web Developer | Version 3.0      Web Development
# 2505  Ultimate Web Developer Course Build 10 Website...      Web Development
# 530   Accounting, Finance and Banking - A Comprehens...     Business Finance
# 3146  The Complete Web Development Course -  Build 1...      Web Development
# 3616  Modern E-Commerce Store In php & mysqli With B...      Web Development
# 3461  Become a Kick-Ass Web Developer: From Newbie t...      Web Development
# ...

# %% [markdown]
# ### Outliers Handling
# - The IQR method was used to detect outliers in the following numerical features
#   'num_subscribers'
#   'num_reviews'
#   'num_lectures'
# - the detected outliers were investigated and found to represent real business values (e.g highly popular coures with a lrge number of subscribers reviewss or lectures) rather then data entry error
#
# - therefore no outliers where removed and all records where retained for further analysis

# %% [markdown]
# ## Metadata Review
# This Section reviews the dataset structure data type and column descriptions to ensure a clear understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3672 non-null   int64
#  1   course_title         3672 non-null   object
#  2   url                  3672 non-null   object
#  3   is_paid              3672 non-null   object
#  4   price                3672 non-null   object
#  5   num_subscribers      3672 non-null   float64
#  6   num_reviews          3672 non-null   float64
#  7   num_lectures         3672 non-null   float64
#  8   level                3672 non-null   object
#  9   content_duration     3672 non-null   object
#  10  published_timestamp  3672 non-null   object
#  11  subject              3672 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 372.9+ KB

# %%
df['price'].unique()
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', 'Free', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '135', 'TRUE', '110'],
#       dtype=object)

# %%
df['price'].value_counts()
# Out:
# price
# 20      830
# 50      467
# Free    310
# 200     294
# 40      216
# 30      169
# 25      153
# 95      152
# 100     133
# 195     127
# 35      115
# 150      88
# 45       83
# 75       80
# 60       75
# 120      37
# 55       35
# 125      30
# 85       30
# 80       29
# 65       28
# 145      27
# 70       26
# 90       19
# 180      17
# 115      16
# 175      13
# 105      11
# 190      10
# 140      10
# 135       8
# 110       7
# 165       6
# 185       6
# 170       5
# 160       4
# 130       3
# 155       2
# TRUE      1
# Name: count, dtype: int64

# %%
# Some Rows Shifted so need to drop them to clean up our analysis
    
df[df['price'] == 'TRUE']
# Out:
#       course_id                                       course_title    url  \
# 2066      96698  Learn Classical Guitar Technique and play 'Spa...  000!"
#
#                                           is_paid price  num_subscribers  \
# 2066  https://www.udemy.com/learnguitartoworship/  TRUE             30.0
#
#       num_reviews  num_lectures level content_duration published_timestamp  \
# 2066       1463.0          29.0    52   Beginner Level             3 hours
#
#                   subject
# 2066  Musical Instruments

# %%
# Save The row shifted 

shifted_row = df.loc[[2066]]

# %%
# Drop shifted row

df.drop(2066, inplace = True)

# %%
# Replasce Error Values

df['price'] = df['price'].replace('Free', 0)

# %%
df['price'].value_counts()
# Out:
# price
# 20     830
# 50     467
# 0      310
# 200    294
# 40     216
# 30     169
# 25     153
# 95     152
# 100    133
# 195    127
# 35     115
# 150     88
# 45      83
# 75      80
# 60      75
# 120     37
# 55      35
# 125     30
# 85      30
# 80      29
# 65      28
# 145     27
# 70      26
# 90      19
# 180     17
# 115     16
# 175     13
# 105     11
# 190     10
# 140     10
# 135      8
# 110      7
# 165      6
# 185      6
# 170      5
# 160      4
# 130      3
# 155      2
# Name: count, dtype: int64

# %%
# Transaction True Metadata

df['price'] = pd.to_numeric(df['price'], errors = 'coerce')

# %%
df.info()

# Done Transaction column price to int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3671 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3671 non-null   int64
#  1   course_title         3671 non-null   object
#  2   url                  3671 non-null   object
#  3   is_paid              3671 non-null   object
#  4   price                3671 non-null   int64
#  5   num_subscribers      3671 non-null   float64
#  6   num_reviews          3671 non-null   float64
#  7   num_lectures         3671 non-null   float64
#  8   level                3671 non-null   object
#  9   content_duration     3671 non-null   object
#  10  published_timestamp  3671 non-null   object
#  11  subject              3671 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 501.9+ KB

# %%
df['content_duration'].unique()
# Out:
# array(['1.5 hours', '39 hours', '2.5 hours', '3 hours', '2 hours',
#        '1 hour', '5 hours', '7 hours', '4 hours', '35 mins', '4.5 hours',
#        '6.5 hours', '10 hours', '5.5 hours', '7.5 hours', '11.5 hours',
#        '16 hours', '3.5 hours', '9 hours', '8.5 hours', '11 hours',
#        '42 mins', '9.5 hours', '218 questions', '18 questions', '33 mins',
#        '62 hours', '8 mins', '41 mins', '31.5 hours', '20 hours',
#        '6 hours', '46.5 hours', '43 mins', '17.5 hours', '12 hours',
#        '32 mins', '24 hours', '19.5 hours', '20.5 hours', '30 mins',
#        '10.5 hours', '31 mins', '36 mins', '8 hours', '29 hours',
#        '26 hours', '24.5 hours', '13 hours', '44 mins', '34 mins',
#        '12.5 hours', '19 mins', '37 mins', '40 mins', '18 hours',
#        '33 hours', '71.5 hours', '47 hours', '14.5 hours', '39 mins',
#        '18.5 hours', '43.5 hours', '38 mins', '14 hours', '28 mins',
#        '24 questions', '45 hours', '70 hours', '0', '29.5 hours',
# ...

# %%
df['content_duration'] = df['content_duration'].str.extract(r"(\d+)").astype(float)

# %%
df['content_duration'].unique()
# Out:
# array([  1.,  39.,   2.,   3.,   5.,   7.,   4.,  35.,   6.,  10.,  11.,
#         16.,   9.,   8.,  42., 218.,  18.,  33.,  62.,  41.,  31.,  20.,
#         46.,  43.,  17.,  12.,  32.,  24.,  19.,  30.,  36.,  29.,  26.,
#         13.,  44.,  34.,  37.,  40.,  71.,  47.,  14.,  38.,  28.,  45.,
#         70.,   0.,  82.,  27.,  21.,  68.,  15.,  78.,  23.,  25.,  60.,
#         22.,  51.,  57.,  76.,  48.,  66.])

# %%
df['Course_Title'].unique()
# Out:
# array(['Ultimate Investment Banking Course',
#        'Complete GST Course & Certification - Grow Your CA Practice',
#        'Financial Modeling for Business Analysts and Consultants', ...,
#        'Learn and Build using Polymer',
#        'CSS Animations: Create Amazing Effects on Your Website',
#        "Using MODX CMS to Build Websites: A Beginner's Guide"],
#       shape=(3658,), dtype=object)

# %%
df['Course_Title'] = df['Course_Title'].str.replace("&", "and")

# %%
df['Course_Title'] = df['Course_Title'].str.replace("Using MODX CMS to Build Websites: A Beginner's Guide",
                                                    "Using MODX CMS to Build Websites A Beginner Guide"
                                                   )

# %%
df['Course_Title'] = df['Course_Title'].str.replace(
    'Complete GST Course and Certification - Grow Your CA Practice',
    'Complete GST Course and Certification Grow Your CA Practice'
)

# %%
df['Course_Title'] = df['Course_Title'].str.replace(
    'CSS Animations: Create Amazing Effects on Your Website',
    'CSS Animations Create Amazing Effects on Your Website'
)

# %%
df['Course_Title'].unique()
# Out:
# array(['Ultimate Investment Banking Course',
#        'Complete GST Course and Certification Grow Your CA Practice',
#        'Financial Modeling for Business Analysts and Consultants', ...,
#        'Learn and Build using Polymer',
#        'CSS Animations Create Amazing Effects on Your Website',
#        'Using MODX CMS to Build Websites A Beginner Guide'],
#       shape=(3658,), dtype=object)

# %%
df['content_duration'].value_counts()
# Out:
# content_duration
# 1.0      1112
# 2.0       687
# 3.0       428
# 4.0       255
# 5.0       202
#          ...
# 46.0        1
# 47.0        1
# 71.0        1
# 218.0       1
# 66.0        1
# Name: count, Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3671 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3671 non-null   int64
#  1   course_title         3671 non-null   object
#  2   url                  3671 non-null   object
#  3   is_paid              3671 non-null   object
#  4   price                3671 non-null   int64
#  5   num_subscribers      3671 non-null   float64
#  6   num_reviews          3671 non-null   float64
#  7   num_lectures         3671 non-null   float64
#  8   level                3671 non-null   object
#  9   content_duration     3671 non-null   float64
#  10  published_timestamp  3671 non-null   object
#  11  subject              3671 non-null   object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 501.9+ KB

# %%
df['published_timestamp'].unique()
# Out:
# array(['2017-01-18T20:58:58Z', '2017-03-09T16:34:20Z',
#        '2016-12-19T19:26:30Z', ..., '2015-12-30T16:41:42Z',
#        '2016-08-11T19:06:15Z', '2014-09-28T19:51:11Z'],
#       shape=(3667,), dtype=object)

# %%
df['published_timestamp'].value_counts()
# Out:
# published_timestamp
# 2017-04-23T16:19:01Z    2
# 2016-05-16T18:28:30Z    2
# 2017-07-02T14:29:35Z    2
# 2014-04-15T21:48:55Z    2
# 2017-01-18T20:58:58Z    1
#                        ..
# 2014-03-31T20:31:04Z    1
# 2017-03-08T18:05:51Z    1
# 2014-04-15T21:52:12Z    1
# 2016-06-08T16:02:39Z    1
# 2014-09-28T19:51:11Z    1
# Name: count, Length: 3667, dtype: int64

# %%
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3671 entries, 0 to 3682
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3671 non-null   int64
#  1   course_title         3671 non-null   object
#  2   url                  3671 non-null   object
#  3   is_paid              3671 non-null   object
#  4   price                3671 non-null   int64
#  5   num_subscribers      3671 non-null   float64
#  6   num_reviews          3671 non-null   float64
#  7   num_lectures         3671 non-null   float64
#  8   level                3671 non-null   object
#  9   content_duration     3671 non-null   float64
#  10  published_timestamp  3671 non-null   datetime64[ns, UTC]
#  11  subject              3671 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2), object(5)
# memory usage: 501.9+ KB

# %%
df['year'] = df['published_timestamp'].dt.year
df['quarter'] = df['published_timestamp'].dt.to_period('Q')
df['month'] = df['published_timestamp'].dt.month
df['week'] = df['published_timestamp'].dt.to_period('W')
df['day'] = df['published_timestamp'].dt.day
# Out:
# C:\Users\AsUs\AppData\Local\Temp\ipykernel_10880\1707030245.py:2: UserWarning:
#
# Converting to PeriodArray/Index representation will drop timezone information.
#
# C:\Users\AsUs\AppData\Local\Temp\ipykernel_10880\1707030245.py:4: UserWarning:
#
# Converting to PeriodArray/Index representation will drop timezone information.

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    TRUE    200
# 1      https://www.udemy.com/goods-and-services-tax/    TRUE     75
# 2  https://www.udemy.com/financial-modeling-for-b...    TRUE     45
# 3  https://www.udemy.com/complete-excel-finance-c...    TRUE     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    TRUE    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0           2147.0         23.0          51.0          All Levels
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3671 entries, 0 to 3682
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3671 non-null   int64
#  1   course_title         3671 non-null   object
#  2   url                  3671 non-null   object
#  3   is_paid              3671 non-null   object
#  4   price                3671 non-null   int64
#  5   num_subscribers      3671 non-null   float64
#  6   num_reviews          3671 non-null   float64
#  7   num_lectures         3671 non-null   float64
#  8   level                3671 non-null   object
#  9   content_duration     3671 non-null   float64
#  10  published_timestamp  3671 non-null   datetime64[ns, UTC]
#  11  subject              3671 non-null   object
#  12  year                 3671 non-null   int32
#  13  quarter              3671 non-null   period[Q-DEC]
#  14  month                3671 non-null   int32
# ...

# %% [markdown]
# ## Replace Values

# %%
df['is_paid'].unique()
# Out:
# array(['TRUE', 'FALSE'], dtype=object)

# %%
df['is_paid'] = df['is_paid'].map({
    'TRUE':'Paid',
    'FALSE': 'Free'
})

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df['level'] = df['level'].map({
    'All Levels': 'All',
    'Intermediate Level': 'Intermediate',
    'Beginner Level': 'Beginner',
    'Expert Level': 'Expert'
})

# %%
df['level'].unique()
# Out:
# array(['All', 'Intermediate', 'Beginner', 'Expert'], dtype=object)

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# ## Rename Columns

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year', 'quarter',
#        'month', 'week', 'day'],
#       dtype='object')

# %%
df.rename(columns = {
    'course_id': 'Course_ID',
    'course_title': 'Course_Title',
    'url': 'URL',
    'is_paid': 'IS_Paid',
    'price': 'Price',
    'num_subscribers': 'Num_Subscribers',
    'num_reviews': 'Num_Reviews',
    'num_lectures': 'Num_Lectures',
    'level': 'Level',
    'content_duration': 'Content_Duration',
    'published_timestamp': 'Published_Timestamp',
    'subject': 'Subject',
    'year': 'Year',
    'quarter': 'Quarter',
    'month': 'Month',
    'week': 'Week',
    'day': 'Day'
}, inplace = True)

# %%
df['Course_Title'].value_counts()
# Out:
# Course_Title
# Creating an animated greeting card via Google Slides            3
# Acoustic Blues Guitar Lessons                                   3
# The Complete Web Developer Masterclass: Beginner To Advanced    2
# MicroStation - Células                                          2
# CFA Level 2- Quantitative Methods                               2
#                                                                ..
# Intro to Photoshop for Merch by Amazon                          1
# Photoshop - Creación de Efectos 2                               1
# Como Criar Logos de Sucesso - Start Designer                    1
# Super Textos con Photoshop                                      1
# Using MODX CMS to Build Websites: A Beginner's Guide            1
# Name: count, Length: 3658, dtype: int64

# %%
df.head(5)
# Out:
#    Course_ID                                       Course_Title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course and Certification Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  URL IS_Paid  Price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    Paid    200
# 1      https://www.udemy.com/goods-and-services-tax/    Paid     75
# 2  https://www.udemy.com/financial-modeling-for-b...    Paid     45
# 3  https://www.udemy.com/complete-excel-finance-c...    Paid     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    Paid    200
#
#    Num_Subscribers  Num_Reviews  Num_Lectures         Level  Content_Duration  \
# 0           2147.0         23.0          51.0           All               1.0
# ...

# %% [markdown]
# ## Metadata Finished
# - Data Preprocessing is completed ready to unlock through analyzing

# %% [markdown]
# ## Now Let`s dive info Exploratory data analysis (EDA) to extract valuble insights

# %% [markdown]
# ===================================
# ==================
#
# ### THE Wed Development and Business Finance Have the Hight Number of Courses in the dataset
# ### while Musical and Graphic design contain fewer courses
#
# ====================================
# ===================

# %%
# what is distribution of courses across

subject_counts = df['Subject'].value_counts()

# bar Chart Visulize using plotly becouse it`s interactive

px.bar(subject_counts)

# %%
#bar_chart= 
df.groupby('Subject').agg(
    median_subscribers=('Num_Subscribers', 'median'),
    Number_of_Courses=('Num_Subscribers', 'count')
)
# Out:
#                      median_subscribers  Number_of_Courses
# Subject
# Business Finance                  921.0               1189
# Graphic Design                    858.0                603
# Musical Instruments               357.5                680
# Web Development                  1627.0               1199

# %% [markdown]
# ===========================
# ==============
#
# ## INSIGHT
#
# ## Suggest that wed development and Business Finance Courses attract more students than other subject
# ## indicating stronger learner demand in these categories
#
# ===========================
# ==============

# %%
px.bar(bar_chart, barmode = 'group',
      title = 'Median Subject VS Num of Courses by subject')

# %% [markdown]
# ==========================
# ===============
#
# ## INSIGHT
#
# # Expert-Level Courses are both fewest in Number(58) and have the lowest median
#
# # subscribers(818.5) showing that users prefer beginner-friendly content over
#
# # advanced material
#
# ===========================
# ===============

# %%
#bar_chart2= 
df.groupby('Level').agg(
    median_level=('Num_Subscribers', 'median'),
    Number_level=('Num_Subscribers', 'count')
).sort_values(by='median_level', ascending = False)
# Out:
#               median_level  Number_level
# Level
# All                  921.0          1925
# Beginner             921.0          1268
# Intermediate         921.0           420
# Expert               818.5            58

# %%
px.bar(bar_chart2, 
       barmode = 'group',
       title = 'Median Level VS Number of Courses by Level'
      )

# %% [markdown]
# =============================
# ==================
#
# ## INSIGHT
#
# ## Ferr courses attract more subscribers despite being fewer in number
#
# =============================
# ===================

# %%
#bar_chart3 = 
df.groupby('IS_Paid').agg(
    Median_sub=('Num_Subscribers', 'median'),
    Num_sub=('Num_Subscribers', 'count')
).sort_values(by = 'Median_sub', ascending = False)
# Out:
#          Median_sub  Num_sub
# IS_Paid
# Free         3326.5      310
# Paid          921.0     3361

# %%
px.bar(bar_chart3,
       barmode = 'group',
       title = 'Median Subscribers VS Number of Courses by Paid'
      )

# %% [markdown]
# ========================
# ===========
#
# ## New Feature Helpe me analyze
#
# =======================
# ===========

# %%
Feature
# Out:
# {'Q1': 228, 'Q3': 1849, 'IQR': 1621, 'upper bound': 4281}

# %%
def subscribers_category(x):
    if x <=1849:
        return('Normal')
    elif x <=4281:
        return('High')
    else:
        return('VIP')


df['Subscribers_Category'] = df['Num_Subscribers'].apply(subscribers_category)  

df.head(5)
# Out:
#    Course_ID                                       Course_Title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course and Certification Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  URL IS_Paid  Price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    Paid    200
# 1      https://www.udemy.com/goods-and-services-tax/    Paid     75
# 2  https://www.udemy.com/financial-modeling-for-b...    Paid     45
# 3  https://www.udemy.com/complete-excel-finance-c...    Paid     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    Paid    200
#
#    Num_Subscribers  Num_Reviews  Num_Lectures         Level  Content_Duration  \
# 0           2147.0         23.0          51.0           All               1.0
# ...

# %%
df['Subscribers_Category'].value_counts()
# Out:
# Subscribers_Category
# Normal    2753
# VIP        491
# High       427
# Name: count, dtype: int64

# %%
category_percent = (
    df['Subscribers_Category']\
        .value_counts(normalize = True)\
        .mul(100)\
        .round(2)\
        .reset_index()
)


category_percent.columns = ['Subscribers_Category',
                            'Percentage'
                           ]
category_percent
# Out:
#   Subscribers_Category  Percentage
# 0               Normal       74.99
# 1                  VIP       13.38
# 2                 High       11.63

# %% [markdown]
# ================================
# ==================
#
# ## INIGHT
#
#
# ## Most courses(75%) fall within the normal subscribers range while only a sample proportion exceed the upper IQR bound and are considered highly exceotional
#
# ===============================
# ==================

# %%
px.pie(category_percent,
       names = 'Subscribers_Category',
       values = 'Percentage',
       title = 'Distribution of Subscribers Catagore',
       hole = 0.5
      )

# %%
#bar_category = 
df.groupby('Subscribers_Category').agg(
    Median_category=('Num_Subscribers', 'median'),
    number_category=('Num_Subscribers', 'count')
)
# Out:
#                       Median_category  number_category
# Subscribers_Category
# High                           2650.0              427
# Normal                          814.0             2753
# VIP                            8320.0              491

# %%
px.bar(bar_category,
       barmode = 'group',
       title = 'Category Subscribers by courses median and Number of subscribers'
      )

# %%
df.columns
# Out:
# Index(['Course_ID', 'Course_Title', 'URL', 'IS_Paid', 'Price',
#        'Num_Subscribers', 'Num_Reviews', 'Num_Lectures', 'Level',
#        'Content_Duration', 'Published_Timestamp', 'Subject', 'Year', 'Quarter',
#        'Month', 'Week', 'Day', 'Subscribers_Category'],
#       dtype='object')

# %%
df['Content_Duration'].value_counts().sort_values(ascending=False).head(20).reset_index()
# Out:
#     Content_Duration  count
# 0                1.0   1112
# 1                2.0    687
# 2                3.0    428
# 3                4.0    255
# 4                5.0    202
# 5                6.0    130
# 6                7.0    101
# 7                8.0     71
# 8                9.0     45
# 9               10.0     45
# 10              37.0     38
# 11              12.0     37
# 12              11.0     33
# 13              32.0     32
# 14              34.0     29
# 15              38.0     28
# 16              31.0     25
# 17              13.0     25
# 18              14.0     23
# 19              40.0     23

# %%
df[['Content_Duration']].describe()
# Out:
#        Content_Duration
# count        3671.00000
# mean            7.16426
# std            11.64343
# min             0.00000
# 25%             1.00000
# 50%             3.00000
# 75%             6.00000
# max           218.00000

# %%
px.scatter(df,
           x = 'Content_Duration',
           y = 'Num_Subscribers',
           title = 'Content Duration VS Number of Subscribers',
           trendline = 'ols',
           render_mode = 'svg'
          )

# %%
duration_analysis = (df.groupby(
    'Content_Duration').agg(
    Median_subscribers=('Num_Subscribers', 'median'),
    Number_of_Coruses=('Num_Subscribers', 'count')
    ).reset_index()
)

# %%
px.line(duration_analysis,
        x = 'Content_Duration',
        y = 'Median_subscribers',
        markers = True,
        title = 'Median Subscribers by Courses Duration'
       )

# %%
#pie_chart = 
df.groupby('Content_Duration').agg(
    Median_subscribers=('Num_Subscribers', 'median'),
    number_subscribers=('Num_Subscribers', 'count')
).sort_values(by = 'Median_subscribers', ascending = False).head(20)
# Out:
#                   Median_subscribers  number_subscribers
# Content_Duration
# 51.0                         37141.0                   1
# 27.0                         34756.5                   2
# 76.0                          7501.0                   1
# 57.0                          7211.0                   1
# 60.0                          6851.0                   1
# 48.0                          6751.0                   1
# 62.0                          5218.0                   2
# 23.0                          4982.0                   3
# 21.0                          4503.0                   3
# 26.0                          3347.5                   4
# 15.0                          2650.0                  13
# 28.0                          2078.0                   2
# 46.0                          1924.0                   1
# 20.0                          1874.5                  14
# 14.0                          1870.0                  23
# ...

# %%
def duration_category(Hours):
    if Hours <=10:
        return('High Demand')
    else:
        return('Low Demand')

df['Duration_Demand'] = df['Content_Duration'].apply(duration_category)

# %%
df['Duration_Demand'].value_counts(normalize = True)\
    .mul(100)\
    .round(2)\
    .reset_index()
# Out:
#   Duration_Demand  proportion
# 0     High Demand       83.82
# 1      Low Demand       16.18

# %%
demand_percent = df.groupby('Duration_Demand')['Num_Subscribers'].sum()\
    .div(df['Num_Subscribers'].sum())\
    .mul(100)\
    .round(2)\
    .reset_index(name = 'Demand_percent'
                )
demand_percent
# Out:
#   Duration_Demand  Demand_percent
# 0     High Demand           79.52
# 1      Low Demand           20.48

# %%
demand_percent.columns = ['Duration_Demand',
                          'percent'
                          ]
demand_percent
# Out:
#   Duration_Demand  percent
# 0     High Demand    79.52
# 1      Low Demand    20.48

# %% [markdown]
# ================================
# ==================
#
# ## INSIGHT
#
# ## Short-duration courses less than 10 dominate the problem attracting 80% of all Subscribers
# ## this highights a clear preference for shorter focused learing experiences
#
#
# ================================
# ===================

# %%
px.pie(demand_percent,
       names = 'Duration_Demand',
       values = 'percent',
       title = 'Distribution of Subscribers Demand',
       hole = 0.5
)

# %% [markdown]
# ## Corr between numeric

# %%
px.scatter(df, 
           x = 'Num_Subscribers',
           y = 'Num_Reviews',
           title = 'Reviews VS Subscribers',
           trendline = 'ols',
           render_mode = 'svg'
          )

# %% [markdown]
# =============================
# =================
#
# ## INSIGHT
#
# ## There is a weak postive relationship between the number of reviews and the number of subscribers
# ## Courses with reviews tend to attract more subscribers although the reletionship is not very strong
#
# =============================
# =============

# %%
px.scatter(df, 
           x = 'Num_Subscribers',
           y = 'Num_Reviews',
           color = 'Duration_Demand',
           title = 'Reviews VS Subscribers by Duration Demand',
           trendline = 'ols',
           render_mode = 'svg'
          )

# %%
px.scatter(df, 
           x = 'Num_Lectures',
           y = 'Num_Subscribers',
           trendline = 'ols',
           render_mode = 'svg'
          )

# %%
px.scatter(df,
           y = 'Num_Subscribers',
           x = 'Price',
           trendline = 'ols',
           render_mode = 'svg'
          )

# %%
plt.figure(figsize=(10, 8))

plt.hist(df['Price'], bins = 30)

plt.title('Distribution of Course Price')

plt.xlabel('Price')

plt.ylabel('Frequency')

plt.show()


## Most courses are price at 25$ making it the dominant price point on the platform 

## this suggest that course creators tend to prefer this price possibly because it represents a competitive or commomly 
## accepled price level

# %%
df[['Price']].describe()


## Not Normal Distrebution
# Out:
#              Price
# count  3671.000000
# mean     65.995642
# std      61.019240
# min       0.000000
# 25%      20.000000
# 50%      45.000000
# 75%      95.000000
# max     200.000000

# %%
#coorr = 
df.corr(numeric_only = True)
# Out:
#                   Course_ID     Price  Num_Subscribers  Num_Reviews  \
# Course_ID          1.000000  0.141036        -0.140611    -0.052062
# Price              0.141036  1.000000         0.040970     0.093459
# Num_Subscribers   -0.140611  0.040970         1.000000     0.489884
# Num_Reviews       -0.052062  0.093459         0.489884     1.000000
# Num_Lectures      -0.018893  0.281826         0.092638     0.144699
# Content_Duration   0.048966  0.012265         0.026669     0.087561
# Year               0.933109  0.131819        -0.156258    -0.049265
# Month             -0.069935  0.039407         0.015342     0.011403
# Day                0.017377  0.012805         0.013487    -0.007819
#
#                   Num_Lectures  Content_Duration      Year     Month       Day
# Course_ID            -0.018893          0.048966  0.933109 -0.069935  0.017377
# Price                 0.281826          0.012265  0.131819  0.039407  0.012805
# ...

# %% [markdown]
# ====================================
# ====================
#
# ## INSIGHT
#
# ## A moderate positive correletion exists between the number of reviews and the subscribers suggesting that coursess with
# ## more reviews tend to attract more learners
#
# ====================================
# ===================
#
# ## INSIGHT
#
# ## Most numerical features show weak or no correletion with the number of subscribers indicationg by multiple
# ## factors is than a single variable
#
# ======================================
# =================

# %%
sns.heatmap(coorr,
            annot = True,
            cmap = 'coolwarm',
            fmt = '.2f'
           )
# Out:
# <Axes: >

# %%
#bar_chart = 
df.groupby('Level').agg(
    Median_Level=('Num_Subscribers', 'median'),
    number_Level=('Num_Subscribers', 'count')
)
# Out:
#               Median_Level  number_Level
# Level
# All                  921.0          1925
# Beginner             921.0          1268
# Expert               818.5            58
# Intermediate         921.0           420

# %%
level_analysis = (df.groupby('Level').agg(
    Median_Level=('Num_Subscribers', 'median'),
    number_Level=('Num_Subscribers', 'count')
).reset_index()
                 )
level_analysis['percent'] = (level_analysis['number_Level'] / level_analysis['number_Level'].sum() * 100).round(2)
level_analysis
# Out:
#           Level  Median_Level  number_Level  percent
# 0           All         921.0          1925    52.44
# 1      Beginner         921.0          1268    34.54
# 2        Expert         818.5            58     1.58
# 3  Intermediate         921.0           420    11.44

# %%
px.pie(level_analysis,
       names = 'Level',
       values = 'percent',
       color = 'number_Level',
       title = 'Subscribers VS Level of percent',
       hole = 0.5
)

# %%
px.bar(bar_chart,
      barmode = 'group'
      )

# %% [markdown]
# ===============================
# ============
#
# ## Calculated Revenue

# %%
df['Revenue'] = df['Price'] * df['Num_Subscribers']

# %%
df.groupby('Subject').agg(
    Total_Revenue=('Revenue', 'sum')\
).sort_values(by = 'Total_Revenue', ascending = False).round(0)
# Out:
#                      Total_Revenue
# Subject
# Web Development        499088380.0
# Business Finance       110753235.0
# Graphic Design          66159020.0
# Musical Instruments     45613655.0

# %%
df.columns
# Out:
# Index(['Course_ID', 'Course_Title', 'URL', 'IS_Paid', 'Price',
#        'Num_Subscribers', 'Num_Reviews', 'Num_Lectures', 'Level',
#        'Content_Duration', 'Published_Timestamp', 'Subject', 'Year', 'Quarter',
#        'Month', 'Week', 'Day', 'Duration_Demand', 'Subscribers_Category',
#        'Revenue'],
#       dtype='object')

# %%
Total = df.groupby('Subscribers_Category').agg(
    Total_Revenue=('Revenue', 'sum')\
).reset_index().sort_values(by = 'Total_Revenue', ascending = False).round(0)


Total.columns = ['Subscribers_Category',
                 'Total_Revenue'
                ]

Total['Revenue_Percent'] = (Total['Total_Revenue'] / Total['Total_Revenue'].sum() * 100).round(2)

Total
# Out:
#   Subscribers_Category  Total_Revenue  Revenue_Percent
# 2                  VIP    515166760.0            71.39
# 1               Normal    119519985.0            16.56
# 0                 High     86927545.0            12.05

# %%
px.pie(Total,
       names = 'Subscribers_Category',
       values = 'Revenue_Percent',
       title = 'percent Total Revenue by Subscribers Category',
       hole = 0.5
      )

# %%
px.bar(Total,
       x = 'Subscribers_Category',
       y = 'Total_Revenue',
       title = 'Total Revenue Per Subscribers of Category',
       barmode = 'group'
      )

# %% [markdown]
# ==============================
# =================
#
# ## INSIGHT
#
# ## Web develpment consistenly generates the highest percentage of revenue across all subscribe category (Normal, High, and VIP)
# ## indicating strong and consistent demand regardless of subscriber segmant
#
# ===============================
# ==================

# %%
subject_revenue = df.groupby(['Subscribers_Category', 'Subject']).agg(
    Total_Revenue=('Revenue', 'sum')
).reset_index()


subject_revenue['revenue_persent'] = (subject_revenue.groupby('Subscribers_Category')['Total_Revenue'].transform(
    lambda x: x / x.sum() * 100).round(2))

                            
subject_revenue
# Out:
#    Subscribers_Category              Subject  Total_Revenue  revenue_persent
# 0                  High     Business Finance     25888085.0            29.78
# 1                  High       Graphic Design     11319450.0            13.02
# 2                  High  Musical Instruments      5072655.0             5.84
# 3                  High      Web Development     44647355.0            51.36
# 4                Normal     Business Finance     41793210.0            34.97
# 5                Normal       Graphic Design     17289805.0            14.47
# 6                Normal  Musical Instruments     15116980.0            12.65
# 7                Normal      Web Development     45319990.0            37.92
# 8                   VIP     Business Finance     43071940.0             8.36
# 9                   VIP       Graphic Design     37549765.0             7.29
# 10                  VIP  Musical Instruments     25424020.0             4.94
# ...

# %%
px.bar(subject_revenue,
       x = 'Subscribers_Category',
       y = 'revenue_persent',
       color = 'Subject',
       barmode = 'group',
       title = 'Revenue Percent Distribution by Subject Per Category'
      )

# %%
line_chart = df.groupby(df['Published_Timestamp'].dt.year)\
                                ['Num_Subscribers'].median().reset_index()

line_chart.columns = ['Year','Median_Sibscribers']

px.line(line_chart,
        x = 'Year',
        y = 'Median_Sibscribers',
        title = 'Median Subscribers Over Year'
       )

# %%
line_chart = df.groupby(df['Published_Timestamp'].dt.year)\
                                ['Course_ID'].nunique().reset_index()

line_chart.columns = ['Year','Number_of_Course']

px.line(line_chart,
        x = 'Year',
        y = 'Number_of_Course',
        title = 'Number of Course Over Year'
       )

# %%
line_chart = df.groupby([df['Published_Timestamp'].dt.year, 'Subscribers_Category'
                        ])['Num_Subscribers'].sum().reset_index()

line_chart.columns = ['Year', 'Subscribers_Category','Total_Sibscribers']

px.line(line_chart,
        x = 'Year',
        y = 'Total_Sibscribers',
        color = 'Subscribers_Category',
        title = 'Median Subscribers Over Year'
       )

# %%
line_chart2 = df.groupby([df['Published_Timestamp'].dt.year, 'Subscribers_Category'
                        ])['Revenue'].sum().reset_index()

line_chart2.columns = ['Year', 'Subscribers_Category','Total_Revenue']

px.line(line_chart2,
        x = 'Year',
        y = 'Total_Revenue',
        color = 'Subscribers_Category',
        title = 'Median Subscribers Over Year'
       )

# %%
df['Quarter_period'] = df['Published_Timestamp'].dt.to_period('Q')

line_chart2 = df[df['Quarter_period'] >='2014'].groupby(['Quarter_period', 'Subscribers_Category'
                        ])['Revenue'].sum().reset_index()

line_chart2 = line_chart2.sort_values('Quarter_period')

line_chart2['Quarter_period'] = line_chart2['Quarter_period'].astype(str)

line_chart2.columns = ['Quarter', 'Subscribers_Category','Total_Revenue']

px.line(line_chart2,
        x = 'Quarter',
        y = 'Total_Revenue',
        color = 'Subscribers_Category',
        title = 'Total Revenue Over Quarter'
       )
# Out:
# C:\Users\AsUs\AppData\Local\Temp\ipykernel_10880\4218308711.py:1: UserWarning:
#
# Converting to PeriodArray/Index representation will drop timezone information.

# %%
df.columns
# Out:
# Index(['Course_ID', 'Course_Title', 'URL', 'IS_Paid', 'Price',
#        'Num_Subscribers', 'Num_Reviews', 'Num_Lectures', 'Level',
#        'Content_Duration', 'Published_Timestamp', 'Subject', 'Year', 'Quarter',
#        'Month', 'Week', 'Day', 'Subscribers_Category', 'Duration_Demand',
#        'Revenue'],
#       dtype='object')

# %%
top_10 = df.nlargest(10, 'Num_Subscribers')


fig = px.bar(top_10,
             x = 'Num_Subscribers',
             y = 'Course_Title',
             orientation = 'h',
             title = 'Top 10 Courses By Number of Subscribers',
             text = 'Num_Subscribers')

fig.update_layout(
    yaxis = dict(categoryorder = 'total ascending'
                ))

# %%
top_10 = df.nlargest(10, 'Revenue')

fig = px.bar(top_10,
        x = 'Revenue',
        y = 'Course_Title',
        orientation = 'h',
        title = 'Top 10 Courses By Revenue',
        text = 'Revenue'
       )

fig.update_layout(
    yaxis = dict(categoryorder = 'total ascending')
)

# %%
top_10 = df.nlargest(10, 'Num_Reviews')

fig = px.bar(top_10,
             x = 'Num_Reviews',
             y = 'Course_Title',
             orientation = 'h',
             title = 'Top 10 Courses By Reviews',
             text = 'Num_Reviews'
            )

fig.update_layout(
    yaxis = dict(categoryorder = 'total ascending')
)

# %% [markdown]
# ===================================
# ====================
#
# # Combined Insight:
# # The top course changes depending on the metric used, showing that popularity, revenue, and engagement don't always align. "Learn HTML5 Programming From Scratch" dominates by subscribers (268k), yet it doesn't appear in the top 10 for Revenue or Reviews — suggesting many of these subscribers came through free or low-priced enrollment rather than paid demand. In contrast, "The Web Developer Bootcamp" leads both the Revenue and Reviews charts, indicating it attracts fewer but higher-paying, more engaged students. This shows that high subscriber counts alone don't guarantee strong financial performance or learner engagement — pricing strategy and course depth likely play a bigger role in driving revenue and reviews than raw popularity.
#
# # Thank you
#
# ====================================
# ===================

# %%
df.to_csv('Udemy_Preprocessing.csv', index = False)
print('transaction Sucssefully')
# Out:
# transaction Sucssefully

# %%
df
# Out:
#       Course_ID                                       Course_Title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course and Certification Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3678     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3679    1088178  How To Design A WordPress Website With No Codi...
# 3680     635248                      Learn and Build using Polymer
# 3681     905096  CSS Animations Create Amazing Effects on Your ...
# 3682     297602  Using MODX CMS to Build Websites A Beginner Guide
#
#                                                     URL IS_Paid  Price  \
# 0     https://www.udemy.com/ultimate-investment-bank...    Paid    200
# ...
